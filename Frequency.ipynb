# %% [markdown]
# # Libraries

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

from collections import Counter

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# # Import Data

# %%
data = pd.read_csv('data/data_full_sentiment.csv')

# %%
data = data.dropna()
data
# Out:
#      Candidate        Date                                           Headline  \
# 0        trump  2016-10-01                        Trump and the Intellectuals
# 1        trump  2016-10-01                                    The Other Trump
# 2        trump  2016-10-01             Trump Infrastructure Plan’s Fatal Flaw
# 3        trump  2016-10-01                 Donald Trump’s Pathetic Fraternity
# 4        trump  2016-10-01                   How Could Anyone Vote for Trump?
# 5        trump  2016-10-01  Donald Trump Opens New Line of Attack on Hilla...
# 6        trump  2016-10-01  Report That Donald Trump Did Business in Cuba ...
# 7        trump  2016-10-01  After Trump-Clinton, Vice-Presidential Debate ...
# 8        trump  2016-10-01  Donald Trump Is Seen as Helping Push Asian-Ame...
# 9        trump  2016-10-01                           Girl Talk at Trump Tower
# 10       trump  2016-10-02                               Donald Trump’s Taxes
# 11       trump  2016-10-02                                Trump’s Tax Records
# 12       trump  2016-10-02         Alicia Machado vs. Donald Trump’s Machismo
# 13       trump  2016-10-02  How Donald Trump Turned the Tax Code Into a Gi...
# 15       trump  2016-10-02  The Time I Found Donald Trump’s Tax Records in...
# 16       trump  2016-10-02  Donald Trump’s Taxes: What We Know and Don’t Know
# 17       trump  2016-10-02  ‘S.N.L.’ Begins a New Season With Alec Baldwin...
# 18       trump  2016-10-02  Donald Trump Tax Records Show He Could Have Av...
# 19       trump  2016-10-02  Donald Trump and His Allies Struggle to Move P...
# 20       trump  2016-10-03                              The Trump Possibility
# 21       trump  2016-10-03                           Trump’s Fellow Travelers
# 22       trump  2016-10-03                       Trump’s Tax (Avoidance) Plan
# 23       trump  2016-10-03                     James Stewart on Trump’s Taxes
# 25       trump  2016-10-03                        Clinton Hits Trump on Taxes
# 27       trump  2016-10-03  Donald Trump Says a Strong Defense Against Cyb...
# 28       trump  2016-10-03  State Attorney General Orders Trump Foundation...
# 29       trump  2016-10-03        9 Times Donald Trump Complained About Taxes
# 30       trump  2016-10-04                     Mr. Trump’s Government Bailout
# 31       trump  2016-10-04                       Trump, Taxes and Citizenship
# 32       trump  2016-10-04  Gomez Addams, Donald Trump and the Art of Failing
# ...        ...         ...                                                ...
# 1530   clinton  2016-11-17  Judge Napolitano: The gross mismanagement of o...
# 1531   clinton  2016-11-18  Mall Santa loses job for telling girl Hillary ...
# 1532   clinton  2016-11-18  Fake news and the election: Why Facebook is po...
# 1533   clinton  2016-11-18  John Legend says Donald Trump's 'Hitler-like' ...
# 1534   clinton  2016-11-19  Sanctuary city mayors vow to fight Trump's dep...
# 1535   clinton  2016-11-19  Obama blocks new oil, gas drilling in Arctic O...
# 1536   clinton  2016-11-20  BIAS ALERT: NYT accused by its public editor o...
# 1537   clinton  2016-11-21  No federal charges for motorist with anti-Clin...
# 1538   clinton  2016-11-22    Trump walks back pledge to pursue Clinton probe
# 1539   clinton  2016-11-22  Critics can't stomach Trump's clean slate for ...
# 20                                   Trump, Possibility
# 21                             Trump, Fellow, Travelers
# 22                    Trump, Tax, (, Avoidance, ), Plan
# 23                         James, Stewart, Trump, Taxes
# 25                          Clinton, Hits, Trump, Taxes
# 27    Donald, Trump, Says, Strong, Defense, Cyberatt...
# 28    State, Attorney, General, Orders, Trump, Found...
# 29           9, Times, Donald, Trump, Complained, Taxes
# 30                       Mr, Trump, Government, Bailout
# 31                         Trump, ,, Taxes, Citizenship
# 32        Gomez, Addams, ,, Donald, Trump, Art, Failing
# ...                                                 ...
# 1530  Judge, Napolitano, :, gross, mismanagement, na...
# 1531  Mall, Santa, loses, job, telling, girl, Hillar...
# 1532  Fake, news, election, :, Facebook, polluting, ...
# 1533  John, Legend, says, Donald, Trump, ', Hitler, ...
# 1534  Sanctuary, city, mayors, vow, fight, Trump, de...
# 1535  Obama, blocks, new, oil, ,, gas, drilling, Arc...
# 1536  BIAS, ALERT, :, NYT, accused, public, editor, ...
# 1537  federal, charges, motorist, anti, -, Clinton, ...
# 1538       Trump, walks, pledge, pursue, Clinton, probe
# 1539     Critics, stomach, Trump, clean, slate, Clinton
# 1540          Conway, :, plan, pursue, charges, Clinton
# 1541  Conservatives, seek, special, prosecutor, Clinton
# 1542  Academics, ,, lawyers, push, Clinton, seek, el...
# 1543  Jordan, :, Congress, obligation, oversight, Cl...
# 1544  Supporters, push, Hillary, campaign, seek, rec...
# 1545  100, percent, Consumer, Financial, Protection,...
# 1546  Rep, Darrell, Issa, continued, investigation, ...
# 1547   Clinton, campaign, joins, effort, recount, votes
# 1548  Rep, Issa, reacts, Trump, downplays, Clinton, ...
# 1549  Trump, calls, Stein, ,, Clinton, vote, recount...
# 1550  Hillary, Clinton, joins, campaign, recount, votes
# 1551  Trump, transition, team, reacts, Clinton, join...
# 1552  Clinton, joining, vote, recount, appears, test...
# 1553  Trump, claims, millions, people, voted, illega...
# 1554  Clinton, joins, recount, effort, Trump, calls,...
# 1555  States, reject, Trump, claim, illegal, ballots...
# 1556          Buzz, :, Hillary, Clinton, sore, loser, ?
# 1557  Hurt, :, Clinton, support, Steins, recount, ef...
# 1558  Republicans, push, :, Debate, seeking, recount...
# 1559           Chaffetz, Clinton, probe, :, simply, let
#
#                         Headline_Stopwords  \
# 0                                 and, the
# 1                               The, Other
# 2                                       ’s
# 3                                       ’s
# 4                  How, Could, Anyone, for
# 5                              of, on, Her
# 6                   That, Did, in, the, in
# 7                  After, Is, n’t, the, of
# 8                             Is, as, Into
# 9                                       at
# 10                                      ’s
# 11                                      ’s
# 12                                      ’s
# 13                       How, the, Into, a
# 15                      The, I, ’s, in, My
# 16              ’s, What, We, and, Do, n’t
# 17                             a, With, as
# 18    Show, He, Could, Have, for, Two, The
# 19                      and, His, to, Move
# 20                                     The
# 21                                      ’s
# 22                                      ’s
# 23                                  on, ’s
# 25                                      on
# 27                          a, Against, Is
# 28                                  to, in
# 29                                   About
# 30                                      ’s
# 31                                     and
# 1540  Conway, :, No, plan, to, pursue, charges, agai...
# 1541  Conservatives, seek, special, prosecutor, for,...
# 1542  Academics, ,, lawyers, push, Clinton, to, seek...
# 1543  Jordan, :, Congress, has, obligation, to, do, ...
# 1544  Supporters, push, Hillary, campaign, to, seek,...
# 1545  100, percent, of, Consumer, Financial, Protect...
# 1546  Rep, Darrell, Issa, on, the, continued, invest...
# 1547  Clinton, campaign, joins, effort, to, recount,...
# 1548  Rep, Issa, reacts, after, Trump, downplays, Cl...
# 1549  Trump, calls, Stein, ,, Clinton, vote, recount...
# 1550  Hillary, Clinton, joins, campaign, to, recount...
# 1551  Trump, transition, team, reacts, to, Clinton, ...
# 1552  Clinton, joining, vote, recount, appears, to, ...
# 1553  Trump, claims, millions, of, people, voted, il...
# 1554  Clinton, joins, recount, effort, that, Trump, ...
# 1555  States, reject, Trump, 's, claim, that, illega...
# 1556  Your, Buzz, :, Is, Hillary, Clinton, a, sore, ...
# 1557  Hurt, :, Clinton, should, not, support, Steins...
# 1558  Republicans, push, back, :, Debate, over, seek...
# 1559  Chaffetz, on, Clinton, probe, :, We, ca, n't, ...
#
#                                        Sentiment_Values Sentiment  \
# 0     [{'neg': 0.0, 'neu': 0.536, 'pos': 0.464, 'com...       neu
# 1     [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 2     [{'neg': 0.467, 'neu': 0.533, 'pos': 0.0, 'com...       neu
# 3     [{'neg': 0.552, 'neu': 0.448, 'pos': 0.0, 'com...       neg
# 4     [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 5     [{'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compo...       neu
# 6     [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 7     [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 8     [{'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compo...       neu
# 9     [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 10    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 11    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 12    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 13    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 15    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 16    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 17    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 18    [{'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compo...       neu
# 19    [{'neg': 0.187, 'neu': 0.813, 'pos': 0.0, 'com...       neu
# 20    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 21    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 22    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 23    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 25    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 27    [{'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'com...       neu
# 28    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 29    [{'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'com...       neu
# 30    [{'neg': 0.318, 'neu': 0.682, 'pos': 0.0, 'com...       neu
# 31    [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 32    [{'neg': 0.292, 'neu': 0.708, 'pos': 0.0, 'com...       neu
# ...                                                 ...       ...
# 1530  [{'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compo...       neu
# 1531  [{'neg': 0.173, 'neu': 0.827, 'pos': 0.0, 'com...       neu
# 1532  [{'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'com...       neu
# 1533  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1534  [{'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'com...       neu
# 1535  [{'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'com...       neu
# 1536  [{'neg': 0.307, 'neu': 0.536, 'pos': 0.157, 'c...       neu
# 1537  [{'neg': 0.417, 'neu': 0.583, 'pos': 0.0, 'com...       neu
# 1538  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1539  [{'neg': 0.426, 'neu': 0.574, 'pos': 0.0, 'com...       neu
# 1540  [{'neg': 0.417, 'neu': 0.583, 'pos': 0.0, 'com...       neu
# 1541  [{'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'com...       neu
# 1542  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1543  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1544  [{'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'com...       neu
# 1545  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1546  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1547  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1548  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1549  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1550  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1551  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1552  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1553  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1554  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# 1555  [{'neg': 0.368, 'neu': 0.468, 'pos': 0.164, 'c...       neu
# 1556  [{'neg': 0.541, 'neu': 0.459, 'pos': 0.0, 'com...       neg
# 1557  [{'neg': 0.485, 'neu': 0.515, 'pos': 0.0, 'com...       neu
# 1558  [{'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'com...       neu
# 1559  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
#
#       Headline_polarity
# 0                0.3818
# 1                0.0000
# 2               -0.5423
# 3               -0.5719
# 4                0.0000
# 5               -0.4767
# 6                0.0000
# 7                0.0000
# 8                0.2960
# 9                0.0000
# 10               0.0000
# 11               0.0000
# 12               0.0000
# 13               0.0000
# 15               0.0000
# 16               0.0000
# 17               0.0000
# 18              -0.3400
# 19              -0.3182
# 20               0.0000
# 21               0.0000
# 22               0.0000
# 23               0.0000
# 25               0.0000
# 27               0.5859
# 28               0.0000
# 29              -0.4019
# 30              -0.1027
# 31               0.0000
# 32              -0.5106
# ...                 ...
# 1530            -0.4767
# 1531            -0.3182
# 1532            -0.4767
# 1533             0.0000
# 1534            -0.3818
# 1535            -0.2263
# 1536            -0.2023
# 1537            -0.5106
# 1538             0.0000
# 1539            -0.5358
# 1540            -0.5106
# 1541             0.4019
# 1542             0.0000
# 1543             0.0000
# 1544             0.4404
# 1545             0.0000
# 1546             0.0000
# 1547             0.0000
# 1548             0.0000
# 1549             0.0000
# 1550             0.0000
# 1551             0.0000
# 1552             0.0000
# 1553             0.0000
# 1554             0.0000
# 1555            -0.5423
# 1556            -0.7096
# 1557            -0.6866
# 1558             0.5719
# 1559             0.0000
#
# [1491 rows x 11 columns]

# %% [markdown]
# # General Frequency

# %%
def wordextractdf(df, col):
    """
    Extract words in the dataframe

    Inputs:
    df -- dataframe
    col -- set of words that we can extract ('keywords', 'hashtags',...)

    Outputs:
    wordsfreq - Counter containing a list of words and its frequency in the dataframe
    """
    words = df[col][df[col].isnull() == False]
    lst = [w for word in words for w in word.split(",")]
    return Counter(lst)

def calc_freq(df, col):
    kw = wordextractdf(df, col)
    dictlist = [[key, value] for key, value in kw.items()]
    freq_df = pd.DataFrame()
    freq_df['words'] = [i[0] for i in dictlist]
    freq_df['freq_total'] = [i[1] for i in dictlist]
    return freq_df

sorted(wordextractdf(data, 'Headline_Keywords').most_common())
freq = calc_freq(data, 'Headline_Keywords')

# %%
freq['words'] = freq['words'].apply(lambda x: x.strip())
freq['words'] = freq['words'].apply(lambda x: x.lower())
freq.drop(freq.index[freq['words'].isin(['',' ', ':','?','-',"'",'’','‘','(',')'])], inplace = True)
freq_clean= freq.pivot_table(index='words', values ='freq_total', aggfunc = 'sum').sort_values(by=['freq_total'], ascending=False)
freq_clean = freq_clean.reset_index()

freq_clean.head()
# Out:
#       words  freq_total
# 0     trump         921
# 1   clinton         439
# 2    donald         335
# 3   hillary         154
# 4  election          74

# %%
#freq_clean.to_csv('data/frequency_full.csv', index=False)

# %% [markdown]
# # Frequency before the election

# %%
data_prev = data[(data['Date'] < '2016-11-08')]

# %%
sorted(wordextractdf(data_prev, 'Headline_Keywords').most_common())
freq = calc_freq(data_prev, 'Headline_Keywords')

# %%
freq['words'] = freq['words'].apply(lambda x: x.strip())
freq['words'] = freq['words'].apply(lambda x: x.lower())
freq.drop(freq.index[freq['words'].isin(['',' ', ':','?','-',"'",'’','‘','(',')'])], inplace = True)
freq_clean= freq.pivot_table(index='words', values ='freq_total', aggfunc = 'sum').sort_values(by=['freq_total'], ascending=False)
freq_clean = freq_clean.reset_index()

freq_clean.head(20)
# Out:
#            words  freq_total
# 0          trump         591
# 1        clinton         360
# 2         donald         247
# 3        hillary         126
# 4         debate          59
# 5       campaign          54
# 6       election          44
# 7           says          41
# 8         emails          37
# 9            new          36
# 10  presidential          35
# 11     wikileaks          31
# 12         obama          30
# 13           tax          29
# 14         email          29
# 15        voters          26
# 16         women          24
# 17         taxes          18
# 18         g.o.p          18
# 19         final          17

# %%
#freq_clean.to_csv('data/frequency_before_election.csv', index=False)

# %% [markdown]
# # Frequency per Day

# %%
dates = data['Date'].tolist()
dates = set(dates)

# %%
freq_days = []
drop_words = ['',' ','—',':','?','-',"'",'’','‘','(',')','trump','donald','clinton','hillary','white','house','america','election','says','little','1','nov','25-dec','u.s','vote']

for i in dates:
    data_day = data[(data['Date'] == i)]
    sorted(wordextractdf(data_day, 'Headline_Keywords').most_common())
    freq = calc_freq(data_day, 'Headline_Keywords')
    freq['words'] = freq['words'].apply(lambda x: x.strip())
    freq['words'] = freq['words'].apply(lambda x: x.lower())
    freq.drop(freq.index[freq['words'].isin(drop_words)], inplace = True)
    #print(freq.columns)
    freq_clean= freq.pivot_table(index='words', values ='freq_total', aggfunc = 'sum').sort_values(by=['freq_total'], ascending=False)
    freq_clean = freq_clean.reset_index()
    freq_list = freq_clean['words'].tolist()[:5]
   # print(freq_list)
    freq_days_dict = {'Date': i, 'KeyWords': freq_list }
    freq_days.append(freq_days_dict)

# %%
df_freq_days = pd.DataFrame(freq_days)
df_freq_days = df_freq_days.sort_values(by='Date')
df_freq_days
# Out:
#           Date                                           KeyWords
# 41  2016-10-01            [debate, talk, presidential, plan, new]
# 22  2016-10-02               [tax, leaked, return, records, past]
# 46  2016-10-03              [tax, taxes, plan, surrogates, james]
# 5   2016-10-04            [debate, presidential, pence, tax, let]
# 34  2016-10-05                [pence, debate, kaine, mike, g.o.p]
# 29  2016-10-06             [debates, sorry, hype, public, future]
# 21  2016-10-07              [debate, yorkers, tax, parties, lies]
# 39  2016-10-08  [apology, lewd, campaign, transcript, republic...
# 30  2016-10-09           [second, debate, women, abandon, latest]
# 7   2016-10-10       [debate, second, presidential, emails, jail]
# 24  2016-10-11           [emails, threat, jail, victory, offense]
# 59  2016-10-12     [emails, wikileaks, republican, russian, tilt]
# 1   2016-10-13     [women, calls, michelle, intolerable, shaking]
# 23  2016-10-14            [working, obama, class, g.o.p, stories]
# 43  2016-10-15             [campaign, leave, drug, furor, heated]
# 57  2016-10-16      [campaign, loosens, specter, extinction, fan]
# 42  2016-10-17                [rigged, claims, polls, media, new]
# 45  2016-10-18             [emails, bernie, stop, sanders, obama]
# 49  2016-10-19        [debate, melania, analysis, mimics, defend]
# 36  2016-10-20          [debate, accept, presidential, email, wo]
# 2   2016-10-21             [dinner, al, smith, russia, democracy]
# 33  2016-10-22  [foundations, accusers, sue, campaign, different]
# 60  2016-10-23                   [at&t, debate, cubs, 150, races]
# 9   2016-10-24      [democrats, wikileaks, big, democracy, texas]
# 10  2016-10-25                [obama, law, seizing, turn, rising]
# 8   2016-10-26        [campaign, wikileaks, media, g.o.p, dinner]
# 6   2016-10-27                    [dark, push, days, line, khizr]
# 31  2016-10-28             [fbi, abandoned, changes, money, hurt]
# 50  2016-10-29               [email, campaign, new, fbi, freeman]
# 11  2016-10-30             [email, emails, democrats, swing, fbi]
# ..         ...                                                ...
# 52  2016-11-01           [momentum, aim, redirects, f.b.i, comey]
# 58  2016-11-02           [obama, early, helps, scandal, firewall]
# 44  2016-11-03           [voters, melania, presidential, /, poll]
# 37  2016-11-04  [campaign, 2016, investigative, underscore, re...
# 54  2016-11-05            [rally, lead, closing, future, debates]
# 17  2016-11-06                 [email, new, case, campaign, head]
# 27  2016-11-07           [final, voters, campaign, scramble, end]
# 18  2016-11-08     [campaigns, live, campaign, obama, presidency]
# 28  2016-11-09       [president, victory, speech, loss, campaign]
# 14  2016-11-10         [obama, president, elect, years, american]
# 15  2016-11-11    [deliver, policy, religious, foreign, promises]
# 55  2016-11-12  [presidency, rally, lobbies, averted, oblitera...
# 16  2016-11-13               [obama, work, heads, divided, staff]
# 26  2016-11-14     [win, democrats, rural, china, administration]
# 48  2016-11-15         [women, team, looks, hispanic, transition]
# 12  2016-11-16  [women, transition, challenge, rocky, presiden...
# 19  2016-11-17            [yellen, democrats, let, jeff, cabinet]
# 35  2016-11-18            [voted, team, women, cabinet, national]
# 40  2016-11-19          [democrats, obama, f.b.i, facebook, fake]
# 47  2016-11-20  [elect, celebrate, president, nationalists, ba...
# 0   2016-11-21                   [list, iran, deal, school, hand]
# 25  2016-11-22               [new, pursue, times, interview, gun]
# 53  2016-11-23            [betsy, devos, education, sense, nikki]
# 32  2016-11-24      [keeping, pick, cites, conditioning, indiana]
# 51  2016-11-25              [won, romney, listings, troops, adds]
# 3   2016-11-26   [conflicts, recount, senate, integrity, hacking]
# 13  2016-11-27         [castro, recount, fidel, briefing, monday]
# 20  2016-11-28           [recount, meets, petraeus, calls, claim]
# 4   2016-11-29             [recount, support, push, romney, rile]
# 38  2016-11-30                   [mnuchin, steven, 10, right, mr]
#
# [61 rows x 2 columns]

# %%
#df_freq_days.to_csv('data/frequency_days.csv', index=False)

# %% [markdown]
# # Frequency/day - Candidates

# %% [markdown]
# ### Additional stop words

# %%
drop_words = ['',' ','/','—',':','?','-',"'",'’','‘','(',')','trump','donald','clinton','hillary','white','house','america','election',
              'says','little','1','nov','25-dec','u.s','vote','9','$','100','%','1.25', '2005', 'million','..','.','10','2',';','17','150',
              '10th','16','2016','2017','!','000','5','al','wo','stop','154','12','2-to-1','25','42','>','1992','1998','2006','&','67','debate','matter','talk','new',
              'presidential','line','look','80s','916']

# %% [markdown]
# ### Trump

# %%
freq_days = []

data_trump = data[(data['Candidate'] == "trump")]

for i in dates:
    data_day = data_trump[(data_trump['Date'] == i)]
    sorted(wordextractdf(data_day, 'Headline_Keywords').most_common())
    freq = calc_freq(data_day, 'Headline_Keywords')
    freq['words'] = freq['words'].apply(lambda x: x.strip())
    freq['words'] = freq['words'].apply(lambda x: x.lower())
    freq.drop(freq.index[freq['words'].isin(drop_words)], inplace = True)
    
    freq_clean= freq.pivot_table(index='words', values ='freq_total', aggfunc = 'sum').sort_values(by=['freq_total'], ascending=False)
    freq_clean = freq_clean.reset_index()
    freq_list = freq_clean['words'].tolist()[:5]
   
    freq_days_dict = {'Date': i, 'KeyWords': freq_list }
    freq_days.append(freq_days_dict)

# %%
df_freq_days_trump = pd.DataFrame(freq_days)
df_freq_days_trump = df_freq_days_trump.sort_values(by='Date')
df_freq_days_trump
# Out:
#           Date                                           KeyWords
# 41  2016-10-01           [miss, universe, campaign, admits, plan]
# 22  2016-10-02              [tax, return, leaked, taxes, records]
# 46  2016-10-03           [tax, taxes, surrogates, argue, returns]
# 5   2016-10-04             [tax, pence, addams, preparation, led]
# 34  2016-10-05               [pence, kaine, taxes, mike, support]
# 29  2016-10-06           [takes, nevada, hype, campaign, debates]
# 21  2016-10-07                   [tax, tape, amid, report, media]
# 39  2016-10-08    [lewd, apology, republicans, support, probably]
# 30  2016-10-09            [women, second, story, record, remarks]
# 7   2016-10-10      [second, jail, acknowledges, income, watches]
# 24  2016-10-11               [ahead, berates, life, lonely, male]
# 59  2016-10-12        [republican, tape, scary, senate, shackles]
# 1   2016-10-13     [women, calls, times, accusations, suspicious]
# 23  2016-10-14          [press, g.o.p, blames, stories, accusers]
# 43  2016-10-15     [allegations, republican, leave, magnate, man]
# 57  2016-10-16      [ballot, measure, north, officials, opponent]
# 42  2016-10-17          [rigged, claims, rifts, members, network]
# 45  2016-10-18            [obama, big, whining, shameful, people]
# 49  2016-10-19        [polls, melania, schism, raises, religious]
# 36  2016-10-20        [accept, abortion, protest, raises, resist]
# 2   2016-10-21    [democracy, smith, dinner, accelerate, mistake]
# 33  2016-10-22             [accusers, sue, republican, media, mr]
# 60  2016-10-23          [aboard, rally, s.n.l., reveals, results]
# 9   2016-10-24          [big, abandoning, report, media, message]
# 10  2016-10-25     [acknowledges, scion, named, obama, obamacare]
# 8   2016-10-26       [hollywood, media, hotel, leaders, military]
# 6   2016-10-27             [abandoning, race, khizr, lack, media]
# 31  2016-10-28                  [sales, plot, leads, nasty, news]
# 50  2016-10-29   [campaign, adviser, singing, praises, questions]
# 11  2016-10-30              [final, email, aghast, shows, revels]
# ..         ...                                                ...
# 52  2016-11-01           [aim, redirects, missouri, momentum, mr]
# 58  2016-11-02   [taxes, abandoned, sleeping, mississippi, novel]
# 44  2016-11-03             [voters, melania, american, solo, pro]
# 37  2016-11-04               [ally, tax, president, pull, pushes]
# 54  2016-11-05                     [reality, act, map, pack, pen]
# 17  2016-11-06              [age, s.n.l., obama, offstage, owner]
# 27  2016-11-07             [wins, voters, final, scramble, night]
# 18  2016-11-08            [wins, media, adulation, live, victory]
# 28  2016-11-09        [victory, president, career, path, trudeau]
# 14  2016-11-10        [obama, president, cordial, elect, meeting]
# 15  2016-11-11       [foreign, market, policy, sphere, president]
# 55  2016-11-12         [presidency, affect, lies, lobbies, major]
# 16  2016-11-13           [obama, victory, sales, offer, overseas]
# 26  2016-11-14  [china, administration, seeking, picks, presid...
# 48  2016-11-15            [team, looks, transition, right, means]
# 12  2016-11-16         [transition, align, security, long, megyn]
# 19  2016-11-17          [sessions, tests, cabinet, jeff, process]
# 35  2016-11-18          [team, security, national, starts, right]
# 40  2016-11-19      [administration, man, mccain, miners, muslim]
# 47  2016-11-20     [elect, president, ties, business, addressing]
# 0   2016-11-21           [100-day, alt, making, melania, murkier]
# 25  2016-11-22                [advocates, alt, lays, limit, long]
# 53  2016-11-23           [nikki, betsy, devos, haley, ambassador]
# 32  2016-11-24           [pick, accept, money, potential, player]
# 51  2016-11-25           [romney, adds, security, obama, options]
# 3   2016-11-26     [conflicts, battle, risk, nominees, officials]
# 13  2016-11-27           [briefing, monday, calls, castro, elect]
# 20  2016-11-28     [amid, ballots, candidates, concerns, efforts]
# 4   2016-11-29        [bashir, care, chooses, critic, guaranteed]
# 38  2016-11-30  [announces, appointees, commerce, drain, forma...
#
# [61 rows x 2 columns]

# %%
#df_freq_days_trump.to_csv('data/frequency_days_trump.csv', index=False)

# %% [markdown]
# ### Hillary

# %%
freq_days = []

data_clinton = data[(data['Candidate'] == "clinton")]

for i in dates:
    data_day = data_clinton[(data_clinton['Date'] == i)]
    sorted(wordextractdf(data_day, 'Headline_Keywords').most_common())
    freq = calc_freq(data_day, 'Headline_Keywords')
    freq['words'] = freq['words'].apply(lambda x: x.strip())
    freq['words'] = freq['words'].apply(lambda x: x.lower())
    freq.drop(freq.index[freq['words'].isin(drop_words)], inplace = True)
    
    freq_clean= freq.pivot_table(index='words', values ='freq_total', aggfunc = 'sum').sort_values(by=['freq_total'], ascending=False)
    freq_clean = freq_clean.reset_index()
    freq_list = freq_clean['words'].tolist()[:5]
   
    freq_days_dict = {'Date': i, 'KeyWords': freq_list }
    freq_days.append(freq_days_dict)

# %%
df_freq_days_clinton = pd.DataFrame(freq_days)
df_freq_days_clinton = df_freq_days_clinton.sort_values(by='Date')
df_freq_days_clinton
# Out:
#           Date                                           KeyWords
# 41  2016-10-01                  [voters, plan, ads, raised, lead]
# 22  2016-10-02           [bill, accuser, reveals, loyal, machado]
# 46  2016-10-03                [tax, plan, accusers, proxy, kaine]
# 5   2016-10-04           [image, assange, body, question, states]
# 34  2016-10-05             [pence, vice, mike, takes, absolutely]
# 29  2016-10-06               [fbi, debates, johnson, gary, syria]
# 21  2016-10-07   [email, affair, slowing, predictions, president]
# 39  2016-10-08        [campaign, advice, speech, offer, poisoned]
# 30  2016-10-09           [speeches, second, abandon, sexism, nyt]
# 7   2016-10-10           [emails, second, going, accused, sexual]
# 24  2016-10-11            [emails, aides, jail, campaign, threat]
# 59  2016-10-12     [wikileaks, emails, russian, answering, spies]
# 1   2016-10-13          [wikileaks, calls, alex, slipping, night]
# 23  2016-10-14        [working, obama, class, questions, guiding]
# 43  2016-10-15     [wikileaks, obama, campaign, podesta, assange]
# 57  2016-10-16      [campaign, hacked, foundation, email, africa]
# 42  2016-10-17              [covert, tech, accuses, liked, media]
# 45  2016-10-18      [emails, sanders, wikileaks, bernie, running]
# 49  2016-10-19       [wikileaks, melania, abbi, jacobson, julian]
# 36  2016-10-20   [wikileaks, email, abortion, statements, people]
# 2   2016-10-21  [wikileaks, russia, accelerated, september, pi...
# 33  2016-10-22  [campaign, suspicious, outside, philippines, p...
# 60  2016-10-23                 [at&t, cubs, warner, time, aboard]
# 9   2016-10-24     [democrats, wikileaks, warren, adviser, maybe]
# 10  2016-10-25                  [obama, law, poll, emails, shows]
# 8   2016-10-26         [year, wikileaks, campaign, party, dinner]
# 6   2016-10-27          [michelle, campaign, dark, obama, voters]
# 31  2016-10-28          [road, anthony, weiner, emails, campaign]
# 50  2016-10-29                 [email, comey, fbi, records, mess]
# 11  2016-10-30             [probe, democrats, email, emails, fbi]
# ..         ...                                                ...
# 52  2016-11-01         [comey, james, aim, reporters, protective]
# 58  2016-11-02         [early, scandal, obama, pattern, sleeping]
# 44  2016-11-03            [voters, act, questions, lose, melania]
# 37  2016-11-04         [campaign, battle, polling, lead, learned]
# 54  2016-11-05         [surge, political, beyoncé, closing, lead]
# 17  2016-11-06              [campaign, f.b.i, case, comey, email]
# 27  2016-11-07             [final, day, accused, scramble, obama]
# 18  2016-11-08       [campaigns, obama, campaign, feeling, ahead]
# 28  2016-11-09    [loss, campaign, speech, concession, president]
# 14  2016-11-10     [democrats, american, right, leadership, lean]
# 15  2016-11-11           [obama, reflect, path, plouffe, popular]
# 55  2016-11-12             [director, blames, affair, loss, love]
# 16  2016-11-13               [obama, blames, abortion, rep, miss]
# 26  2016-11-14            [democrats, agree, tax, pulling, putin]
# 48  2016-11-15          [women, hispanic, accepts, protect, myth]
# 12  2016-11-16            [women, california, glass, ally, rocky]
# 19  2016-11-17           [democrats, pro, agency, real, majority]
# 35  2016-11-18                    [voted, women, way, pick, ones]
# 40  2016-11-19           [democrats, fake, obama, news, facebook]
# 47  2016-11-20          [bias, celebrate, nyt, public, president]
# 0   2016-11-21  [anti, regret, milwaukee, motorist, neighborhood]
# 25  2016-11-22          [interview, news, pizzeria, fake, pursue]
# 53  2016-11-23       [wing, seek, retreat, obligation, oversight]
# 32  2016-11-24  [listings, supporters, recount, accusations, s...
# 51  2016-11-25          [listings, best, sellers, problem, putin]
# 3   2016-11-26        [recount, stein, democrats, senate, effort]
# 13  2016-11-27          [recount, fidel, castro, joining, monday]
# 20  2016-11-28              [recount, calls, claim, lines, meets]
# 4   2016-11-29      [recount, push, advances, secretary, popular]
# 38  2016-11-30            [steven, mnuchin, affairs, race, north]
#
# [61 rows x 2 columns]

# %%
#df_freq_days_clinton.to_csv('data/frequency_days_clinton.csv', index=False)
