# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
# import random
import re
# import scrapy

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
#key= 'cdb1919e5cf347979a229344269fd6d9'

# %%
#url = 'https://newsapi.org/v2/everything?q=trump&from=2016-11-10&to=2016-11-11&apiKey='+key
#response = requests.get(url)
#results = response.json()

#results

# %%
url = 'https://www.foxnews.com/search-results/search?q=trump&ss=fn&min_date=2016-10-26&max_date=2016-10-26'

html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head profile="http://dublincore.org/documents/dcq-html/">
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <!-- This page is generated from portal v8-www3 -->
# <link href="//global.fncstatic.com/static/v/fn2/img/favicon.png" rel="icon" type="image/png"/>
# <link href="//global.fncstatic.com/static/v/fn2/img/favicon.ico" rel="shortcut icon"/>
# <script type="text/javascript">
# 	var FOX_pagedescriptor = window.FOX_pagedescriptor = {breadcrumb:
# 	"/home", isMgmt: "false", site: "fn2" };
# </script>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.dc"/>
# <link href="http://purl.org/dc/terms/" rel="schema.dcterms"/>
# ...

# %%
data_nyt = pd.read_csv('data/nyt_split.csv')

# %%
data_nyt.head()
# Out:
#   Candidate        Date                                Headline  \
# 0     trump  2016-10-01             Trump and the Intellectuals
# 1     trump  2016-10-01                         The Other Trump
# 2     trump  2016-10-01  Trump Infrastructure Plan’s Fatal Flaw
# 3     trump  2016-10-01      Donald Trump’s Pathetic Fraternity
# 4     trump  2016-10-01        How Could Anyone Vote for Trump?
#
#                                              Snippet
# 0  A case for Trump’s ideas that ignores the man ...
# 1  Unlike her prominent half siblings, Tiffany Tr...
# 2  The Republican nominee has proposed, in effect...
# 3  Chris Christie and Rudy Giuliani once had prid...
# 4  It’s time for Republican leaders to exercise a...

# %%
data_fox = pd.read_csv('data/fox_both_headlines.csv', sep=";", encoding='latin-1')

# %%
data_fox.head()
# Out:
#   Candidate        Date                                           Headline  \
# 0     trump  2016-10-01      John Sununu reverses position, endorses Trump
# 1     trump  2016-10-01  Campaign adviser: Trump wins the debate over t...
# 2     trump  2016-10-01  Women who know Trump defend the GOP candidate'...
# 3     trump  2016-10-01  Trump's economic agenda: Cutting taxes for job...
# 4     trump  2016-10-01  Presidential campaign spiraling downward with ...
#
#        Site
# 0  Fox News
# 1  Fox News
# 2  Fox News
# 3  Fox News
# 4  Fox News

# %%
data_nyt.drop(columns='Snippet', inplace = True)
data_nyt.head()
# Out:
#   Candidate        Date                                Headline
# 0     trump  2016-10-01             Trump and the Intellectuals
# 1     trump  2016-10-01                         The Other Trump
# 2     trump  2016-10-01  Trump Infrastructure Plan’s Fatal Flaw
# 3     trump  2016-10-01      Donald Trump’s Pathetic Fraternity
# 4     trump  2016-10-01        How Could Anyone Vote for Trump?

# %%
data_nyt['Site'] = 'New York Times'

# %%
data_nyt.head()
# Out:
#   Candidate        Date                                Headline  \
# 0     trump  2016-10-01             Trump and the Intellectuals
# 1     trump  2016-10-01                         The Other Trump
# 2     trump  2016-10-01  Trump Infrastructure Plan’s Fatal Flaw
# 3     trump  2016-10-01      Donald Trump’s Pathetic Fraternity
# 4     trump  2016-10-01        How Could Anyone Vote for Trump?
#
#              Site
# 0  New York Times
# 1  New York Times
# 2  New York Times
# 3  New York Times
# 4  New York Times

# %%
#df_titles_split = df_titles_split.append(df_titles_split_clint, ignore_index=True)

data_full = data_nyt.append(data_fox, ignore_index=True)

# %%
data_full
# Out:
#     Candidate        Date                                           Headline  \
# 0       trump  2016-10-01                        Trump and the Intellectuals
# 1       trump  2016-10-01                                    The Other Trump
# 2       trump  2016-10-01             Trump Infrastructure Plan’s Fatal Flaw
# 3       trump  2016-10-01                 Donald Trump’s Pathetic Fraternity
# 4       trump  2016-10-01                   How Could Anyone Vote for Trump?
# 5       trump  2016-10-01  Donald Trump Opens New Line of Attack on Hilla...
# 6       trump  2016-10-01  Report That Donald Trump Did Business in Cuba ...
# 7       trump  2016-10-01  After Trump-Clinton, Vice-Presidential Debate ...
# 8       trump  2016-10-01  Donald Trump Is Seen as Helping Push Asian-Ame...
# 9       trump  2016-10-01                           Girl Talk at Trump Tower
# 10      trump  2016-10-02                               Donald Trump’s Taxes
# ...

# %%
data_full = data_full.dropna()

# %%
data_full
# Out:
#     Candidate        Date                                           Headline  \
# 0       trump  2016-10-01                        Trump and the Intellectuals
# 1       trump  2016-10-01                                    The Other Trump
# 2       trump  2016-10-01             Trump Infrastructure Plan’s Fatal Flaw
# 3       trump  2016-10-01                 Donald Trump’s Pathetic Fraternity
# 4       trump  2016-10-01                   How Could Anyone Vote for Trump?
# 5       trump  2016-10-01  Donald Trump Opens New Line of Attack on Hilla...
# 6       trump  2016-10-01  Report That Donald Trump Did Business in Cuba ...
# 7       trump  2016-10-01  After Trump-Clinton, Vice-Presidential Debate ...
# 8       trump  2016-10-01  Donald Trump Is Seen as Helping Push Asian-Ame...
# 9       trump  2016-10-01                           Girl Talk at Trump Tower
# 10      trump  2016-10-02                               Donald Trump’s Taxes
# ...

# %%
data_full.to_csv('data/data_full.csv', index=False)
