# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data/nyt_sentiment.csv')

# %%
data.head()
# Out:
#          Date                                           Headline  \
# 0  2016-10-01  Donald Trump Opens New Line of Attack on Hilla...
# 1  2016-10-01  Hillary Clinton and Democrats Raised $154 Mill...
# 2  2016-10-01  New Hillary Clinton Ads Look to Expand Lead Wi...
# 3  2016-10-01                   How Could Anyone Vote for Trump?
# 4  2016-10-01  Donald Trump Is Seen as Helping Push Asian-Ame...
#
#                                              Snippet  \
# 0  In an interview, Mr. Trump said he was reconsi...
# 1  Her campaign and the party have a combined cas...
# 2  The Clinton team has made Hispanic outreach a ...
# 3  It’s time for Republican leaders to exercise a...
# 4  Asian-Americans are identifying as Democrats a...
#
#                                     Sentiment_Values Sentiment  \
# 0  [{'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compo...       neu
# 1  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...       neu
# ...

# %%
data_headline_pivot = data.pivot_table(index = 'Date', values = 'Headline_polarity', aggfunc = 'mean')

# %%
data_headline_pivot.head()
# Out:
#             Headline_polarity
# Date
# 2016-10-01          -0.005844
# 2016-10-02           0.000000
# 2016-10-03           0.018930
# 2016-10-04           0.121330
# 2016-10-05          -0.069790
